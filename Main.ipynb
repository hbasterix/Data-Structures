# %% [markdown]
# <a href="https://colab.research.google.com/github/hbasterix/Data-Structures/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a meshgrid for spherical coordinates
u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:50j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)

# Plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='skyblue', edgecolor='gray', alpha=0.7)
ax.set_box_aspect([1,1,1])  # Equal aspect ratio
plt.show()
